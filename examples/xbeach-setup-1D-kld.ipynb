# %%
# import default modules
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D 
from matplotlib import cm
import sys
import os

# method to import xbtools with try routine
try:
    import xbTools
except ImportError:
    print('**no xbTools installation found in environment, adding parent path of notebook to see if it works')
    sys.path.append(os.path.abspath(os.path.join('..', '..', 'xbeach-toolbox')))

# %%
## import specific tools from xbTools
from xbTools.grid.creation import xgrid, ygrid
from xbTools.grid.extension import seaward_extend, lateral_extend
from xbTools.xbeachtools import XBeachModelSetup
from xbTools.general import wave_functions, visualize_mesh

# %%
import pandas as pd

# Process bathy profiles


profile_path = '/home/alson/models/xbeach-toolbox/examples/kld_profiles2.xlsm'

# read the excel file with profiles (colummns are x,easting, northing,depth,dtmx)
df = pd.read_excel(profile_path, header=None)
df = df.rename(columns={'0': 'x', '1': 'depth'})
# print(df)
# create a dictionary to store all dataframes
dfs = {}

# loop through all sheets
for i in range(1, 69):
    sheet_name = f'PR_{i:02d}'  # format the sheet name
    df = pd.read_excel(profile_path, sheet_name=sheet_name, header=None)
    # print(df)
    df.columns = ['x', 'northing','easting', 'depth','dtmx', 'dtmnorthing','dtmeasting', 'dtmdepth']  # Assign meaningful column names

    # Interpolate 'depth' values based on 'x' values with a difference of 1
    x_min = 0
    x_max = df['x'].max()
    new_x = np.arange(x_min, x_max + 1, 1)
    dtmx_min = 0
    dtmx_max = df['x'].max()
    new_dtmx = np.arange(dtmx_min, dtmx_max + 1, 1)


    # Perform linear interpolation
    interpolated_depth = np.interp(new_x, df['x'], df['depth'])

    # Create a new DataFrame with interpolated values
    # interpolated_df = pd.DataFrame({'x': new_x, 'depth': interpolated_depth})

        # Perform linear interpolation
    interpolated_dtmdepth = np.interp(new_dtmx, df['dtmx'], df['dtmdepth'])

    # Create a new DataFrame with interpolated values
    # interpolated_dtmdf = pd.DataFrame({'dtmx': new_dtmx, 'dtmdepth': interpolated_dtmdepth})
# 
    interpolated_df = pd.DataFrame({'x': new_x, 'depth': interpolated_depth}).set_index('x')
    interpolated_dtmdf = pd.DataFrame({'dtmx': new_dtmx, 'dtmdepth': interpolated_dtmdepth}).set_index('dtmx')

    # Choose the maximum between 'depth' and 'dtmdepth' for each corresponding index
    merged_df = pd.DataFrame({'merged_depth': interpolated_df['depth'].combine(interpolated_dtmdf['dtmdepth'], max)})
    
    # Store the merged DataFrame in the dictionary merged to extract later
    dfs[sheet_name] = merged_df



    # plt.plot(merged_df['merged_depth'])
    # plt.plot(interpolated_df['depth'])
    # plt.plot(interpolated_dtmdf['dtmdepth'])
    # Print the interpolated DataFrame
    # print(interpolated_df)
    # print(interpolated_dtmdf)





    # dfs[sheet_name] = df  # store the dataframe in the dictionary
print(dfs)
# Out:
# {'PR_01':        merged_depth
# 0.0        0.974797
# 1.0        0.964504
# 2.0        0.958500
# 3.0        0.990729
# 4.0        0.960967
# ...             ...
# 388.0    -23.354256
# 389.0    -23.343663
# 390.0    -23.330390
# 391.0    -23.316197
# 392.0    -23.309690
#
# [393 rows x 1 columns], 'PR_02':        merged_depth
# 0.0        1.134529
# 1.0        1.198572
# 2.0        1.158820
# 3.0        1.122483
# 4.0        1.099814
# ...             ...
# 449.0    -33.785243
# 450.0    -34.010352
# 451.0    -34.089019
# 452.0    -34.425580
# 453.0    -34.517330
#
# [454 rows x 1 columns], 'PR_03':        merged_depth
# 0.0        3.919000
# 1.0        3.525386
# 2.0        3.059843
# 3.0        2.517403
# 4.0        2.715535
# ...             ...
# 382.0    -38.900258
# 383.0    -38.917915
# 384.0    -38.939096
# 385.0    -39.003523
# 386.0    -39.114437
#
# [387 rows x 1 columns], 'PR_04':        merged_depth
# 0.0        1.352532
# 1.0        1.388151
# 2.0        1.424190
# 3.0        1.452712
# 4.0        1.495847
# ...             ...
# 415.0    -44.701201
# 416.0    -44.809141
# 417.0    -45.565537
# 418.0    -46.580164
# 419.0    -47.188457
#
# [420 rows x 1 columns], 'PR_05':        merged_depth
# 0.0        1.995182
# 1.0        1.775979
# 2.0        1.798473
# 3.0        1.844380
# 4.0        1.969499
# ...             ...
# 352.0    -64.918614
# 353.0    -65.037280
# 354.0    -64.015591
# 355.0    -63.393264
# 356.0    -63.388996
#
# [357 rows x 1 columns], 'PR_06':        merged_depth
# 0.0        1.348000
# 1.0        1.348000
# 2.0        1.348000
# 3.0        1.348000
# 4.0        1.374803
# ...             ...
# 344.0    -60.751065
# 345.0    -61.381056
# 346.0    -62.131850
# 347.0    -62.681947
# 348.0    -62.748001
#
# [349 rows x 1 columns], 'PR_07':        merged_depth
# 0.0        1.316601
# 1.0        1.275970
# 2.0        1.104948
# 3.0        1.027000
# 4.0        1.052261
# ...             ...
# 349.0    -67.179832
# 350.0    -67.547162
# 351.0    -68.064390
# 352.0    -68.132885
# 353.0    -67.733002
#
# [354 rows x 1 columns], 'PR_08':        merged_depth
# 0.0        1.110000
# 1.0        1.110000
# 2.0        1.140649
# 3.0        1.147992
# 4.0        1.150842
# ...             ...
# 342.0    -57.054968
# 343.0    -57.636461
# 344.0    -58.318919
# 345.0    -59.300132
# 346.0    -59.564568
#
# [347 rows x 1 columns], 'PR_09':        merged_depth
# 0.0        1.144000
# 1.0        1.144000
# 2.0        1.144000
# 3.0        1.144000
# 4.0        1.144000
# ...             ...
# 325.0    -50.023898
# 326.0    -50.261717
# 327.0    -50.478804
# 328.0    -50.588300
# 329.0    -50.442650
#
# [330 rows x 1 columns], 'PR_10':        merged_depth
# 0.0        0.812117
# 1.0        0.811631
# 2.0        0.813673
# 3.0        0.836440
# 4.0        0.876739
# ...             ...
# 323.0    -39.081446
# 324.0    -40.140011
# 325.0    -41.604863
# 326.0    -42.878306
# 327.0    -43.039032
#
# [328 rows x 1 columns], 'PR_11':        merged_depth
# 0.0        1.310274
# 1.0        1.291643
# 2.0        1.346426
# 3.0        1.330218
# 4.0        1.350375
# ...             ...
# 351.0    -41.488863
# 352.0    -41.566981
# 353.0    -41.647666
# 354.0    -41.727648
# 355.0    -41.729748
#
# [356 rows x 1 columns], 'PR_12':        merged_depth
# 0.0        1.396917
# 1.0        1.401173
# 2.0        1.419884
# 3.0        1.435309
# 4.0        1.476559
# ...             ...
# 376.0    -37.754489
# 377.0    -37.939459
# 378.0    -38.049189
# 379.0    -38.069735
# 380.0    -38.149666
#
# [381 rows x 1 columns], 'PR_13':        merged_depth
# 0.0        1.453877
# 1.0        1.442826
# 2.0        1.444081
# 3.0        1.428449
# 4.0        1.436406
# ...             ...
# 384.0    -37.801683
# 385.0    -37.736434
# 386.0    -37.853363
# 387.0    -37.960893
# 388.0    -37.978931
#
# [389 rows x 1 columns], 'PR_14':        merged_depth
# 0.0        0.475228
# 1.0        0.424158
# 2.0        0.410046
# 3.0        0.446718
# 4.0        0.501604
# ...             ...
# 371.0    -32.918684
# 372.0    -32.982099
# 373.0    -33.158614
# 374.0    -33.456897
# 375.0    -33.355145
#
# [376 rows x 1 columns], 'PR_15':        merged_depth
# 0.0        1.343596
# 1.0        1.346391
# 2.0        1.349185
# 3.0        1.349534
# 4.0        1.355581
# ...             ...
# 398.0    -36.605593
# 399.0    -36.725728
# 400.0    -36.724012
# 401.0    -36.688761
# 402.0    -36.691250
#
# [403 rows x 1 columns], 'PR_16':        merged_depth
# 0.0        1.293442
# 1.0        1.291819
# 2.0        1.300893
# 3.0        1.334346
# 4.0        1.355618
# ...             ...
# 384.0    -31.467054
# 385.0    -31.668438
# 386.0    -31.894451
# 387.0    -32.165054
# 388.0    -32.176308
#
# [389 rows x 1 columns], 'PR_17':        merged_depth
# 0.0        1.649000
# 1.0        1.587790
# 2.0        1.599945
# 3.0        1.622259
# 4.0        1.654324
# ...             ...
# 397.0    -33.895707
# 398.0    -33.912014
# 399.0    -33.937182
# 400.0    -34.034366
# 401.0    -34.142754
#
# [402 rows x 1 columns], 'PR_18':        merged_depth
# 0.0        1.173834
# 1.0        1.164398
# 2.0        1.165201
# 3.0        1.212465
# 4.0        1.298768
# ...             ...
# 385.0    -34.032140
# 386.0    -34.178321
# 387.0    -34.359914
# 388.0    -34.544726
# 389.0    -34.632603
#
# [390 rows x 1 columns], 'PR_19':        merged_depth
# 0.0        1.032112
# 1.0        1.022747
# 2.0        0.992483
# 3.0        0.983254
# 4.0        0.966791
# ...             ...
# 346.0    -32.920688
# 347.0    -33.011359
# 348.0    -33.056770
# 349.0    -33.111462
# 350.0    -33.176479
#
# [351 rows x 1 columns], 'PR_20':        merged_depth
# 0.0        0.612539
# 1.0        0.612902
# 2.0        0.629219
# 3.0        0.672435
# 4.0        0.694800
# ...             ...
# 320.0    -39.339939
# 321.0    -39.402385
# 322.0    -39.450872
# 323.0    -39.599407
# 324.0    -39.738495
#
# [325 rows x 1 columns], 'PR_21':        merged_depth
# 0.0        1.276848
# 1.0        1.276382
# 2.0        1.275232
# 3.0        1.277693
# 4.0        1.298183
# ...             ...
# 241.0    -39.145026
# 242.0    -39.356665
# 243.0    -39.571879
# 244.0    -39.446811
# 245.0    -39.437817
#
# [246 rows x 1 columns], 'PR_22':        merged_depth
# 0.0        1.089847
# 1.0        1.076517
# 2.0        1.063187
# 3.0        1.078156
# 4.0        1.097788
# ...             ...
# 235.0    -37.911046
# 236.0    -37.947899
# 237.0    -37.966570
# 238.0    -38.094284
# 239.0    -38.104115
#
# [240 rows x 1 columns], 'PR_23':        merged_depth
# 0.0        1.285575
# 1.0        1.275262
# 2.0        1.246535
# 3.0        1.256402
# 4.0        1.288368
# ...             ...
# 243.0    -39.223674
# 244.0    -39.290706
# 245.0    -39.340861
# 246.0    -39.451939
# 247.0    -39.481915
#
# [248 rows x 1 columns], 'PR_24':        merged_depth
# 0.0        0.887445
# 1.0        0.878254
# 2.0        0.873145
# 3.0        0.864967
# 4.0        0.840994
# ...             ...
# 278.0    -38.752572
# 279.0    -38.822290
# 280.0    -38.891228
# 281.0    -38.975938
# 282.0    -38.984734
#
# [283 rows x 1 columns], 'PR_25':        merged_depth
# 0.0        0.845833
# 1.0        0.840288
# 2.0        0.801104
# 3.0        0.838059
# 4.0        0.897431
# ...             ...
# 257.0    -39.386652
# 258.0    -39.397228
# 259.0    -39.410659
# 260.0    -39.410169
# 261.0    -39.410168
#
# [262 rows x 1 columns], 'PR_26':        merged_depth
# 0.0        1.140203
# 1.0        1.138883
# 2.0        1.137789
# 3.0        1.138253
# 4.0        1.136933
# ...             ...
# 262.0    -38.729329
# 263.0    -38.756302
# 264.0    -38.790242
# 265.0    -38.850491
# 266.0    -38.863949
#
# [267 rows x 1 columns], 'PR_27':        merged_depth
# 0.0        1.591000
# 1.0        1.591000
# 2.0        1.591000
# 3.0        1.591000
# 4.0        1.591000
# ...             ...
# 253.0    -38.248713
# 254.0    -38.433289
# 255.0    -38.389005
# 256.0    -38.466475
# 257.0    -38.509182
#
# [258 rows x 1 columns], 'PR_28':        merged_depth
# 0.0        1.205849
# 1.0        1.205849
# 2.0        1.205849
# 3.0        1.205849
# 4.0        1.205849
# ...             ...
# 256.0    -36.036380
# 257.0    -36.111146
# 258.0    -36.191012
# 259.0    -36.307399
# 260.0    -36.450603
#
# [261 rows x 1 columns], 'PR_29':        merged_depth
# 0.0        0.903822
# 1.0        0.903822
# 2.0        0.903822
# 3.0        0.903822
# 4.0        0.903822
# ...             ...
# 283.0    -35.933831
# 284.0    -35.980306
# 285.0    -35.981877
# 286.0    -35.885974
# 287.0    -35.882915
#
# [288 rows x 1 columns], 'PR_30':        merged_depth
# 0.0        1.882000
# 1.0        1.882000
# 2.0        1.882000
# 3.0        1.882000
# 4.0        1.882000
# ...             ...
# 300.0    -37.010270
# 301.0    -37.026812
# 302.0    -37.022596
# 303.0    -37.055382
# 304.0    -37.065136
#
# [305 rows x 1 columns], 'PR_31':        merged_depth
# 0.0        0.884224
# 1.0        0.897497
# 2.0        0.910770
# 3.0        0.924044
# 4.0        0.935498
# ...             ...
# 314.0    -38.496522
# 315.0    -38.518967
# 316.0    -38.533735
# 317.0    -38.592094
# 318.0    -38.597771
#
# [319 rows x 1 columns], 'PR_32':        merged_depth
# 0.0        0.871778
# 1.0        0.824603
# 2.0        0.827904
# 3.0        0.848996
# 4.0        0.870110
# ...             ...
# 324.0    -40.813791
# 325.0    -40.872620
# 326.0    -40.952176
# 327.0    -41.034383
# 328.0    -41.074528
#
# [329 rows x 1 columns], 'PR_33':        merged_depth
# 0.0        0.904794
# 1.0        0.930327
# 2.0        0.956223
# 3.0        0.981393
# 4.0        1.007521
# ...             ...
# 301.0    -38.622098
# 302.0    -38.674379
# 303.0    -38.898249
# 304.0    -38.994982
# 305.0    -39.005821
#
# [306 rows x 1 columns], 'PR_34':        merged_depth
# 0.0        1.221807
# 1.0        1.240940
# 2.0        1.251231
# 3.0        1.252823
# 4.0        1.261538
# ...             ...
# 339.0    -38.101020
# 340.0    -38.101753
# 341.0    -38.099436
# 342.0    -38.112241
# 343.0    -38.140987
#
# [344 rows x 1 columns], 'PR_35':        merged_depth
# 0.0        0.821167
# 1.0        0.823977
# 2.0        0.856882
# 3.0        0.879031
# 4.0        0.888410
# ...             ...
# 349.0    -38.499739
# 350.0    -38.460871
# 351.0    -38.413886
# 352.0    -38.277640
# 353.0    -38.274414
#
# [354 rows x 1 columns], 'PR_36':        merged_depth
# 0.0        1.549375
# 1.0        1.502598
# 2.0        1.432303
# 3.0        1.364167
# 4.0        1.214406
# ...             ...
# 311.0    -33.048302
# 312.0    -33.291203
# 313.0    -33.417541
# 314.0    -33.412286
# 315.0    -33.298920
#
# [316 rows x 1 columns], 'PR_37':        merged_depth
# 0.0        1.014231
# 1.0        1.055822
# 2.0        1.062648
# 3.0        1.084586
# 4.0        1.094711
# ...             ...
# 345.0    -31.836298
# 346.0    -31.756032
# 347.0    -31.799068
# 348.0    -31.762551
# 349.0    -31.750004
#
# [350 rows x 1 columns], 'PR_38':        merged_depth
# 0.0        1.325607
# 1.0        1.331182
# 2.0        1.341635
# 3.0        1.349140
# 4.0        1.348863
# ...             ...
# 346.0    -31.810575
# 347.0    -31.842663
# 348.0    -31.878642
# 349.0    -31.920555
# 350.0    -31.925526
#
# [351 rows x 1 columns], 'PR_39':        merged_depth
# 0.0        0.918323
# 1.0        0.941709
# 2.0        0.964128
# 3.0        0.980395
# 4.0        1.003230
# ...             ...
# 533.0    -30.806411
# 534.0    -31.116441
# 535.0    -31.097322
# 536.0    -31.040609
# 537.0    -30.921492
#
# [538 rows x 1 columns], 'PR_40':        merged_depth
# 0.0        1.117176
# 1.0        1.121350
# 2.0        1.127177
# 3.0        1.102156
# 4.0        1.109362
# ...             ...
# 527.0    -31.625991
# 528.0    -31.662953
# 529.0    -31.654894
# 530.0    -31.651182
# 531.0    -31.649706
#
# [532 rows x 1 columns], 'PR_41':        merged_depth
# 0.0        0.443000
# 1.0        0.443000
# 2.0        0.443000
# 3.0        0.443000
# 4.0        0.443000
# ...             ...
# 594.0    -32.175523
# 595.0    -32.188243
# 596.0    -32.231699
# 597.0    -32.273217
# 598.0    -32.279938
#
# [599 rows x 1 columns], 'PR_42':        merged_depth
# 0.0        0.766065
# 1.0        0.897014
# 2.0        0.912431
# 3.0        0.926958
# 4.0        0.846952
# ...             ...
# 527.0    -30.741236
# 528.0    -30.784178
# 529.0    -30.829273
# 530.0    -30.906074
# 531.0    -31.067455
#
# [532 rows x 1 columns], 'PR_43':        merged_depth
# 0.0        1.172758
# 1.0        1.159432
# 2.0        1.141436
# 3.0        1.128235
# 4.0        1.114533
# ...             ...
# 489.0    -31.311108
# 490.0    -31.179621
# 491.0    -31.180923
# 492.0    -31.182290
# 493.0    -31.183395
#
# [494 rows x 1 columns], 'PR_44':        merged_depth
# 0.0        1.234571
# 1.0        1.249266
# 2.0        1.275970
# 3.0        1.265316
# 4.0        1.274532
# ...             ...
# 514.0    -30.927809
# 515.0    -30.980011
# 516.0    -31.027944
# 517.0    -31.068127
# 518.0    -31.094000
#
# [519 rows x 1 columns], 'PR_45':        merged_depth
# 0.0        1.226143
# 1.0        1.221369
# 2.0        1.212485
# 3.0        1.211811
# 4.0        1.212354
# ...             ...
# 535.0    -31.201671
# 536.0    -31.263280
# 537.0    -31.337809
# 538.0    -31.412083
# 539.0    -31.451563
#
# [540 rows x 1 columns], 'PR_46':        merged_depth
# 0.0        1.436000
# 1.0        1.436000
# 2.0        1.365975
# 3.0        1.332556
# 4.0        1.373755
# ...             ...
# 332.0    -24.192909
# 333.0    -24.287690
# 334.0    -24.625322
# 335.0    -24.741533
# 336.0    -24.863010
#
# [337 rows x 1 columns], 'PR_47':        merged_depth
# 0.0        1.409429
# 1.0        1.420819
# 2.0        1.433071
# 3.0        1.451646
# 4.0        1.442290
# ...             ...
# 462.0    -28.873024
# 463.0    -28.786882
# 464.0    -28.696826
# 465.0    -28.680136
# 466.0    -28.653044
#
# [467 rows x 1 columns], 'PR_48':        merged_depth
# 0.0        1.420600
# 1.0        1.453888
# 2.0        1.425731
# 3.0        1.398130
# 4.0        1.380075
# ...             ...
# 471.0    -28.615640
# 472.0    -28.677148
# 473.0    -28.791389
# 474.0    -28.635370
# 475.0    -28.547714
#
# [476 rows x 1 columns], 'PR_49':        merged_depth
# 0.0        1.259900
# 1.0        1.271879
# 2.0        1.296912
# 3.0        1.303393
# 4.0        1.298305
# ...             ...
# 451.0    -28.699035
# 452.0    -28.679524
# 453.0    -28.662434
# 454.0    -28.647238
# 455.0    -28.644657
#
# [456 rows x 1 columns], 'PR_50':        merged_depth
# 0.0        1.510096
# 1.0        1.512563
# 2.0        1.514187
# 3.0        1.557987
# 4.0        1.557852
# ...             ...
# 398.0    -30.635184
# 399.0    -30.763821
# 400.0    -30.873618
# 401.0    -30.987680
# 402.0    -31.056351
#
# [403 rows x 1 columns], 'PR_51':        merged_depth
# 0.0        1.631625
# 1.0        1.588796
# 2.0        1.563414
# 3.0        1.594023
# 4.0        1.582373
# ...             ...
# 510.0    -30.572074
# 511.0    -30.596321
# 512.0    -30.622107
# 513.0    -30.667985
# 514.0    -30.674767
#
# [515 rows x 1 columns], 'PR_52':        merged_depth
# 0.0        1.714273
# 1.0        1.721819
# 2.0        1.719764
# 3.0        1.687437
# 4.0        1.687227
# ...             ...
# 509.0    -31.582075
# 510.0    -31.563842
# 511.0    -31.567547
# 512.0    -31.572527
# 513.0    -31.574228
#
# [514 rows x 1 columns], 'PR_53':        merged_depth
# 0.0        0.734834
# 1.0        0.400106
# 2.0        0.294607
# 3.0        0.202242
# 4.0        0.111638
# ...             ...
# 518.0    -32.239610
# 519.0    -32.307585
# 520.0    -32.353901
# 521.0    -32.396078
# 522.0    -32.408031
#
# [523 rows x 1 columns], 'PR_54':        merged_depth
# 0.0        1.538333
# 1.0        1.546772
# 2.0        1.534654
# 3.0        1.526115
# 4.0        1.515062
# ...             ...
# 557.0    -33.802231
# 558.0    -33.817923
# 559.0    -33.949884
# 560.0    -34.150740
# 561.0    -34.176044
#
# [562 rows x 1 columns], 'PR_55':        merged_depth
# 0.0        1.582727
# 1.0        1.568586
# 2.0        1.514169
# 3.0        1.524060
# 4.0        1.495812
# ...             ...
# 565.0    -34.041815
# 566.0    -34.079130
# 567.0    -34.114737
# 568.0    -34.188400
# 569.0    -34.206001
#
# [570 rows x 1 columns], 'PR_56':        merged_depth
# 0.0        1.460324
# 1.0        1.471640
# 2.0        1.472838
# 3.0        1.481362
# 4.0        1.495247
# ...             ...
# 535.0    -34.245805
# 536.0    -34.274207
# 537.0    -34.293543
# 538.0    -34.305150
# 539.0    -34.311832
#
# [540 rows x 1 columns], 'PR_57':        merged_depth
# 0.0        1.494125
# 1.0        1.489456
# 2.0        1.467668
# 3.0        1.456846
# 4.0        1.462504
# ...             ...
# 538.0    -34.143803
# 539.0    -34.159323
# 540.0    -34.182491
# 541.0    -34.288474
# 542.0    -34.292881
#
# [543 rows x 1 columns], 'PR_58':        merged_depth
# 0.0        1.501000
# 1.0        1.506474
# 2.0        1.491698
# 3.0        1.509803
# 4.0        1.527241
# ...             ...
# 363.0    -34.292458
# 364.0    -34.330684
# 365.0    -34.373057
# 366.0    -34.404976
# 367.0    -34.410294
#
# [368 rows x 1 columns], 'PR_59':        merged_depth
# 0.0        1.517625
# 1.0        1.205112
# 2.0        0.823240
# 3.0        0.525193
# 4.0        0.361756
# ...             ...
# 333.0    -24.300034
# 334.0    -24.382534
# 335.0    -24.409143
# 336.0    -24.576229
# 337.0    -24.633770
#
# [338 rows x 1 columns], 'PR_60':        merged_depth
# 0.0        1.732167
# 1.0        1.760320
# 2.0        1.759145
# 3.0        1.760020
# 4.0        1.782186
# ...             ...
# 543.0    -30.860197
# 544.0    -31.621756
# 545.0    -31.672582
# 546.0    -31.912993
# 547.0    -32.204723
#
# [548 rows x 1 columns], 'PR_61':        merged_depth
# 0.0        1.321536
# 1.0        1.324227
# 2.0        1.327418
# 3.0        1.331159
# 4.0        1.335234
# ...             ...
# 560.0    -34.164540
# 561.0    -34.284591
# 562.0    -34.444072
# 563.0    -34.636296
# 564.0    -34.805225
#
# [565 rows x 1 columns], 'PR_62':        merged_depth
# 0.0        1.807429
# 1.0        1.783770
# 2.0        1.831465
# 3.0        1.789631
# 4.0        1.783595
# ...             ...
# 264.0    -34.377658
# 265.0    -34.485398
# 266.0    -34.491020
# 267.0    -34.397590
# 268.0    -34.391808
#
# [269 rows x 1 columns], 'PR_63':        merged_depth
# 0.0        1.934675
# 1.0        2.026931
# 2.0        2.159885
# 3.0        2.294122
# 4.0        2.430755
# ...             ...
# 292.0    -33.234547
# 293.0    -33.583805
# 294.0    -33.718124
# 295.0    -33.724367
# 296.0    -33.720150
#
# [297 rows x 1 columns], 'PR_64':        merged_depth
# 0.0        1.664650
# 1.0        1.642984
# 2.0        1.611331
# 3.0        1.591759
# 4.0        1.624321
# ...             ...
# 345.0    -37.809003
# 346.0    -37.804835
# 347.0    -37.767006
# 348.0    -37.744637
# 349.0    -37.743839
#
# [350 rows x 1 columns], 'PR_65':        merged_depth
# 0.0        1.504222
# 1.0        1.506797
# 2.0        1.523784
# 3.0        1.450774
# 4.0        1.444068
# ...             ...
# 445.0    -32.224686
# 446.0    -32.214164
# 447.0    -32.242023
# 448.0    -32.289651
# 449.0    -32.292221
#
# [450 rows x 1 columns], 'PR_66':        merged_depth
# 0.0        1.100000
# 1.0        1.100000
# 2.0        1.100000
# 3.0        1.100000
# 4.0        1.100000
# ...             ...
# 483.0    -27.350238
# 484.0    -27.364706
# 485.0    -27.380070
# 486.0    -27.392109
# 487.0    -27.397223
#
# [488 rows x 1 columns], 'PR_67':        merged_depth
# 0.0        0.600505
# 1.0        0.641662
# 2.0        0.669562
# 3.0        0.716703
# 4.0        0.748117
# ...             ...
# 521.0    -27.504577
# 522.0    -27.517387
# 523.0    -27.612842
# 524.0    -27.644691
# 525.0    -27.646372
#
# [526 rows x 1 columns], 'PR_68':        merged_depth
# 0.0        1.112334
# 1.0        1.159910
# 2.0        1.107540
# 3.0        1.080810
# 4.0        1.081204
# ...             ...
# 392.0    -22.002653
# 393.0    -21.866150
# 394.0    -21.774317
# 395.0    -21.767033
# 396.0    -21.763308
#
# [397 rows x 1 columns]}

# %%
# loop through all profiles and get physical parameters for BEWARE interpolation
for i in range(63, 64): # total of 68 profiles for Kulhudhuffushi island
    sheet_name = f'PR_{i:02d}'  # format the sheet name
    ## load data
    bathy_df = dfs[sheet_name]
    # Extract depths from the DataFrame and convert to numpy array
    bathy = bathy_df['merged_depth'].values
    x=bathy_df['merged_depth'].index.values
    # print(x)
    # Define the subset range
    subset_indices = np.where((bathy >= -6) & (bathy <= -3.5)) # pretty arbitrary values but they work for most of the profiles here
    flat_indices = np.where((bathy >= -2) & (bathy <= -0.4)) #for reef flat values
    plot_indices = np.where((bathy >= -20) & (bathy <= 0)) #for plotting the fore reef slope
    
    
    # Fit a straight line to the forereef subset
    coefficients = np.polyfit(x[subset_indices], bathy[subset_indices], 1)
    line_fit = np.poly1d(coefficients)

    # Fit a straight line to the flat subset (some reef flats are sloped)
    flat_depth = np.mean(bathy[flat_indices]) #taking an average of depths between -0.4 and -2m
    flat_fit = np.poly1d(np.array([0,flat_depth])) # this is not required but left in case the approach changes

    # Plot the original bathy data
    plt.plot(x, bathy, label='Original Bathy')

    #Beach Crest Elevation
    beach_indices = np.where((bathy >= 0)) # pretty arbitrary values but they work for most of the profiles here
    crest_elevation=np.max(bathy[beach_indices])

    print(crest_elevation)
    # Calculate the derivative of bathy values
    bathy_derivative = np.gradient(bathy[::10], x[::10])

    # Plot the fitted straight line for the forereef
    plt.plot(x[plot_indices], line_fit(x[plot_indices]), label='Fore_reef slope')

    # Plot the fitted straight line for the reef flat
    plt.plot(x[flat_indices], flat_fit(x[flat_indices]), label='Reef flat')

    # Plot the differentiation of bathy values
    plt.plot(x[::10], bathy_derivative*5, label='Bathy Derivative')

    # Plot settings
    plt.xlabel('X')
    plt.ylabel('Bathy')
    plt.title('Fitted lines for reef parameters')
    plt.legend()
    plt.grid(True)
    plt.ylim(-20,5)
    plt.show()
# Out:
# 2.851421606521128

# %%
# Initialize an empty list to store depths and corresponding x values
bathy_list = []

for i in range(37, 38):
    sheet_name = f'PR_{i:02d}' 

    ## load data
    bathy_df = dfs[sheet_name]
    # Extract depths from the DataFrame and convert to numpy array
    bathy = bathy_df['merged_depth'].values
    # Reverse the bathy values
    bathy = np.flip(bathy)

    ## set bathy grid
    nx = len(bathy)
    # ny = 72
    dx = 1
    # dy = 20

    x = np.linspace(0,(nx-1)*dx,nx)

    ## plot
    plt.figure()
    plt.plot(x,bathy)
    plt.xlabel('x [m]')
    plt.ylabel('z [m]')
    plt.grid('on')
    plt.title('bathy')

# %%
xgr,zgr = xgrid(x, bathy,dxmin=1)


plt.figure()
plt.plot(x,bathy,'-o')
plt.plot(xgr,zgr,'.-')
plt.legend(['Bathy','xgr'])
plt.xlabel('x [m]')
plt.ylabel('z [m]')
plt.grid('on')

# %%
zgr = np.interp(xgr, x, bathy)

plt.figure()
plt.plot(x,bathy,'-o')
plt.plot(xgr,zgr,'.-')
plt.xlabel('x [m]')
plt.ylabel('x [m]')
plt.title('xb bathy')
plt.grid('on')

# %%
xgr, ygr, zgr = seaward_extend(xgr,[0],zgr,slope=1/20000000000000000,depth=min(zgr))
plt.figure()
plt.plot(xgr.T,zgr[:,:].T)
plt.xlabel('x [m]')
plt.ylabel('z [m]')
# Out:
# Text(0, 0.5, 'z [m]')

# %%
xb_setup = XBeachModelSetup('Test kld')

# print(xb_setup)

# %%
xb_setup.set_grid(xgr,None,zgr,posdwn=-1)

# xb_setup.set_waves('parametric',{'Hm0':2, 'Tp':5, 'mainang':270, 'gammajsp':3.3, 's' : 10000, 'fnyq':1})
xb_setup.set_waves('jonstable',{'Hm0':[1.5, 2, 1.5],'Tp':[4, 5, 4],'gammajsp':[3.3, 3.3, 3.3], 's' : [20,20,20], 'mainang':[270,280, 290],'duration':[3600, 3600, 3600],'dtbc':[1,1,1]})

xb_setup.set_params({'wavemodel':'surfbeat',
                     'morphology':0,
                     'befriccoef':0.01,
                     'tstop':3600,
                     'zs0':0,
                     'nglobalvar':['zb','zs','H'],
                     'npointvar':['zs','zb'],
                     'nmeanvar':['zb'],
                     'sedtrans':0,
                     'instat':'jons',
                     'npoints':['1 0', '6 0', '10 0', '12 0']})

sim_path = os.path.join('xb-1D')
if not os.path.exists(sim_path):
    os.mkdir(sim_path)
xb_setup.write_model(sim_path)

# %%
print(sim_path)
# Out:
# xb-1D

# %%
xb_setup = XBeachModelSetup('Test kld')
import os


# Define the path to xbeach.exe
xbpath = r'C:\Users\Rendering\Downloads\xbeach_5848_x64_mpi_netcdf\xbeach.exe'

def create_runxb_bat(xbpath, bat_file_path):
    # Define the content of the batch file
    batch_content = f'mpiexec -np 16 -localonly "{xbpath}"'

    # Write the content to runxb.bat file
    with open(bat_file_path, 'w') as file:
        file.write(batch_content)

# Define the path for the runxb.bat file
bat_file_path = os.path.join(sim_path, 'runxb.bat')

# Create runxb.bat file
create_runxb_bat(xbpath, bat_file_path)


def copy_mpiexec(path_sim):
    # Assuming mpiexec.exe is in the current working directory
    source = 'C:/Users/alson/OneDrive/Documents/mpiexec.exe'
    shutil.copy(source, path_sim)


# # Create runxb.bat file
# create_runxb_bat(xbpath)

# Define the destination folder to copy mpiexec.exe
destination_folder = os.path.dirname(sim_path)

# Copy mpiexec.exe to the destination folder
copy_mpiexec(sim_path)

print('success')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 36
#      33 destination_folder = os.path.dirname(sim_path)
#      35 # Copy mpiexec.exe to the destination folder
# ---> 36 copy_mpiexec(sim_path)
#      38 print('success')
#
# Cell In[15], line 26, in copy_mpiexec(path_sim)
#      23 def copy_mpiexec(path_sim):
#      24     # Assuming mpiexec.exe is in the current working directory
#      25     source = 'C:/Users/alson/OneDrive/Documents/mpiexec.exe'
# ---> 26     shutil.copy(source, path_sim)
#
# NameError: name 'shutil' is not defined

# %%
import subprocess

# Run the batch file as administrator
subprocess.run(['runas', '/user:Administrator', bat_file_path])
# Out:
# CompletedProcess(args=['runas', '/user:Administrator', 'xb-1D\\runxb.bat'], returncode=1)

# %%
sim_path = r'D:\KLD'

# %%
import os
import shutil
from xbTools.xbeachtools import XBeachModelSetup

def create_runxb_bat(xbpath, bat_file_path):
    # Define the content of the batch file
    batch_content = f'mpiexec -np 30 -mapall "{xbpath}"'

    # Write the content to runxb.bat file
    with open(bat_file_path, 'w') as file:
        file.write(batch_content)




def copy_mpiexec(path_sim):
    # Assuming mpiexec.exe is in the current working directory
    source = '/mnt/d/KLD/mpiexec.exe'
    shutil.copy(source, path_sim)

# Define the ranges for each variable
Hm0_range = np.arange(1.5, 3.1, 0.5)
Tp_range = np.arange(5, 16, 5)
cf_values = [0.01, 0.1]
zs0_range = np.arange(0, 1.61, 0.2)

# Nested loop through each variable
for Hm0 in Hm0_range:
    for Tp in Tp_range:
        for cf in cf_values:
            for zs0 in zs0_range:

                
                # Initialize an empty list to store depths and corresponding x values
                bathy_list = []
                for i in range(4, 69,4):
                    sheet_name = f'PR_{i:02d}' 
                    # Generate folder name based on variable values
                    folder_name = f'{sheet_name}+Hs={Hm0:.3g}-Tp={Tp:.3g}-cf={cf:.3g}-zs0={zs0:.3g}'
                    ## load data
                    bathy_df = dfs[sheet_name]
                    # Extract depths from the DataFrame and convert to numpy array
                    bathy = bathy_df['merged_depth'].values
                    # Reverse the bathy values
                    bathy = np.flip(bathy)

                    ## set bathy grid
                    nx = len(bathy)
                    dx = 1

                    x = np.linspace(0, (nx-1)*dx, nx)
                    xgr, zgr = xgrid(x, bathy, dxmin=1)
                    zgr = np.interp(xgr, x, bathy)
                    xgr, ygr, zgr = seaward_extend(xgr, [0], zgr, slope=1/20, depth=min(zgr))

                    xb_setup = XBeachModelSetup('Test kld')
                    xb_setup.set_grid(xgr, None, zgr, posdwn=-1)

                    xb_setup.set_waves('parametric', {'Hm0': Hm0, 'Tp': Tp, 'mainang': 270, 'gammajsp': 3.3, 's': 10000, 'fnyq': 1})
                    # xb_setup.set_waves('jonstable',{'Hm0':Hm0,'Tp':Tp,'gammajsp':[3.3], 's' : [20], 'mainang':[270],'duration':[3600],'dtbc':[1]})

                    xb_setup.set_params({'wavemodel': 'nonh',
                                         'nonh': '1',
                                         'secorder': '1',
                                         'nhbreaker': '1',
                                         'instat':'jons',
                                         'front':'nonh_1d',
                                         'back':'wall',
                                         'ARC': '1',
                                         'order': '1',
                                         'CFL': '0.3',
                                         'morphology': 0,
                                         'befriccoef': cf,
                                         'tstop': 3600,
                                         'zs0': zs0,
                                         'nglobalvar': ['zb', 'zs'],
                                         'nmeanvar': ['zb'],
                                         'sedtrans': 0,
                                         'tintg' : 1,
                                         'tintp' : 1,
                                         })

                    sim_path = os.path.join('/mnt/d/KLD/run3', folder_name)
                    print(sim_path)
                    if not os.path.exists(sim_path):
                        os.makedirs(sim_path)  # Use makedirs to create nested directories
                    xb_setup.write_model(sim_path)
                    # Define the path to xbeach.exe
                    xbpath = r'D:\KLD\XBeach_Kingsday\xbeach.exe'

                    # Define the path for the runxb.bat file
                    bat_file_path = os.path.join(sim_path, 'runxb.bat')

                    # Create runxb.bat file
                    create_runxb_bat(xbpath, bat_file_path)


                    # # Create runxb.bat file
                    # create_runxb_bat(xbpath)

                    # Define the destination folder to copy mpiexec.exe
                    destination_folder = os.path.dirname(sim_path)

                    # Copy mpiexec.exe to the destination folder
                    copy_mpiexec(sim_path)

                    params_file_path = os.path.join(sim_path, 'params.txt')

                    # Open the text file in read mode because this stupid xbtools package is so limited
                    with open(params_file_path, 'r') as file:
                        lines = file.readlines()

                    # Insert new lines after the 28th line
                    lines.insert(27, 'instat = jons\n')
                    lines.insert(28, 'ARC = 1\n')
                    lines.insert(29, 'nhbreaker = 1\n')
                    lines.insert(30, 'secorder = 1\n')

                    # Open the text file in write mode and write the modified lines
                    with open(params_file_path, 'w') as file:
                        file.writelines(lines)
                    print('success')
                    plt.close('all')
# Out:
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=10-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=10-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=10-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=10-cf=0.1-zs0=0.6
# ...
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=15-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=15-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=15-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# /mnt/d/KLD/run2/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# wbctype=parametric cannot be plotted
# success
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os

def delete_mpich_exe(directory):
    # Iterate over each folder in the specified directory
    for root, dirs, files in os.walk(directory):
        for file in files:
            # Check if the file is named "mpich.exe"
            # print(file)
            if file == "mpiexec.exe":
                # Construct the full path to the file
                file_path = os.path.join(root, file)
                print(file_path)
                try:
                    # Delete the file
                    os.remove(file_path)
                    print(f"Deleted {file_path}")
                except Exception as e:
                    print(f"Error deleting {file_path}: {e}")

# Specify the directory to search
directory_to_search = '/mnt/d/KLD/run2'

# Call the function to delete mpich.exe from each folder in the specified directory
delete_mpich_exe(directory_to_search)
# Out:
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_01+Hs=1.5-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# ...
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=10-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.8/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1.6/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.2/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.4/mpiexec.exe
# /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe
# Deleted /mnt/d/KLD/run2/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.6/mpiexec.exe

# %%
print(sim_path)
# Out:
# /mnt/d/KLD/PR_68+Hs=3-Tp=15-cf=0.1-zs0=1.6

# %%
## import xbeach tools
#sys.path.append(os.path.abspath(os.path.join('..')))

from xbTools.xbeachpost import XBeachModelAnalysis
results = XBeachModelAnalysis('Test kld', '/examples/xb-1D/')
results.metadata
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[19], line 5
#       1 ## import xbeach tools
#       2 #sys.path.append(os.path.abspath(os.path.join('..')))
#       4 from xbTools.xbeachpost import XBeachModelAnalysis
# ----> 5 results = XBeachModelAnalysis('Test kld', '/examples/xb-1D/')
#       6 results.metadata
#
# File ~/miniforge3/envs/xbenv/lib/python3.12/site-packages/xbTools/xbeachpost.py:38, in XBeachModelAnalysis.__init__(self, fname, model_path)
#      36 self.fname = fname
#      37 self.model_path = model_path
# ---> 38 self.get_params()
#      39 self.get_metadata()
#      41 # self.params = None
#
# File ~/miniforge3/envs/xbenv/lib/python3.12/site-packages/xbTools/xbeachpost.py:135, in XBeachModelAnalysis.get_params(self)
#     129 """
#     130 reads parameters from params
#     131 """
#     133 #todo: better to read these from the xbeach.log instead of the params.txt
# --> 135 assert os.path.exists(os.path.join(self.model_path, 'params.txt')), 'missing params.txt'
#     137 f = open(os.path.join(self.model_path, 'params.txt'), 'r')
#     138 dat = f.read().split('\n')
#
# AssertionError: missing params.txt

# %%
zs = results.load_modeloutput('zs')
print(zs)
ny, nx = results.var['globalx'].shape

results.load_modeloutput('point_zs')

zs = results.get_modeloutput('zs')
point_zs = results.get_modeloutput('point_zs')
print(zs)
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

# Assuming zs is a 2D numpy array
line, = ax.plot(zs[0, 0])

def update(num):
    line.set_ydata(zs[num, 0])  # update the data.
    return line,

for g in range(0,3600):
    ani = animation.FuncAnimation(fig, update, frames=range(3600), interval=100, blit=True)

    plt.show()
# Out:
# loading model output coordinates from file
# loading variable zs from file
# None
# loading variable point_zs from file
# [[[0.0 0.0 0.0 ... -- -- --]]
#
#  [[2.7318273591307448e-05 3.6922968768609525e-05 1.9544798773500468e-06
#    ... 0.9631616648016449 -- --]]
#
#  [[0.00014622172609823718 0.00017226252030701255 2.955243026889504e-05
#    ... 0.9631616648016449 -- --]]
#
#  ...
#
#  [[0.005611864594385663 0.0057360838628522206 0.02021909742060482 ...
#    0.9631616648016449 -- --]]
#
#  [[0.008726349476208997 0.009428303687625286 0.028693751127729986 ...
#    0.9631616648016449 -- --]]
#
#  [[0.015271408886182275 0.01665422447703537 0.03607694527524885 ...
#    0.9631616648016449 -- --]]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[109], line 23
#      20     return line,
#      22 for g in range(0,3600):
# ---> 23     ani = animation.FuncAnimation(fig, update, frames=range(3600), interval=100, blit=True)
#      25     plt.show()
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\animation.py:1695, in FuncAnimation.__init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1692 # Needs to be initialized so the draw functions work without checking
#    1693 self._save_seq = []
# -> 1695 super().__init__(fig, **kwargs)
#    1697 # Need to reset the saved seq, since right now it will contain data
#    1698 # for a single frame from init, which is not what we want.
#    1699 self._save_seq = []
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\animation.py:1417, in TimedAnimation.__init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1415 if event_source is None:
#    1416     event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1417 super().__init__(fig, event_source=event_source, *args, **kwargs)
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\animation.py:888, in Animation.__init__(self, fig, event_source, blit)
#     885 self._close_id = self._fig.canvas.mpl_connect('close_event',
#     886                                               self._stop)
#     887 if self._blit:
# --> 888     self._setup_blit()
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\animation.py:1211, in Animation._setup_blit(self)
#    1209 self._drawn_artists = []
#    1210 # _post_draw needs to be called first to initialize the renderer
# -> 1211 self._post_draw(None, self._blit)
#    1212 # Then we need to clear the Frame for the initial draw
#    1213 # This is typically handled in _on_resize because QT and Tk
#    1214 # emit a resize event on launch, but the macosx backend does not,
#    1215 # thus we force it here for everyone for consistency
#    1216 self._init_draw()
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\animation.py:1166, in Animation._post_draw(self, framedata, blit)
#    1164     self._blit_draw(self._drawn_artists)
#    1165 else:
# -> 1166     self._fig.canvas.draw_idle()
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\backends\backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\axis.py:1391, in Axis.draw(self, renderer, *args, **kwargs)
#    1388 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1390 for tick in ticks_to_draw:
# -> 1391     tick.draw(renderer)
#    1393 # Shift label away from axes to avoid overlapping ticklabels.
#    1394 self._update_label_position(renderer)
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\axis.py:295, in Tick.draw(self, renderer)
#     292 renderer.open_group(self.__name__, gid=self.get_gid())
#     293 for artist in [self.gridline, self.tick1line, self.tick2line,
#     294                self.label1, self.label2]:
# --> 295     artist.draw(renderer)
#     296 renderer.close_group(self.__name__)
#     297 self.stale = False
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\text.py:797, in Text.draw(self, renderer)
#     793             textrenderer.draw_tex(gc, x, y, clean_line,
#     794                                   self._fontproperties, angle,
#     795                                   mtext=mtext)
#     796         else:
# --> 797             textrenderer.draw_text(gc, x, y, clean_line,
#     798                                    self._fontproperties, angle,
#     799                                    ismath=ismath, mtext=mtext)
#     801 gc.restore()
#     802 renderer.close_group('text')
#
# File c:\Users\alson\.conda\envs\era5_eva\Lib\site-packages\matplotlib\backends\backend_agg.py:194, in RendererAgg.draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     191 font = self._prepare_font(prop)
#     192 # We pass '0' for angle here, since it will be rotated (in raster
#     193 # space) in the following call to draw_text_image).
# --> 194 font.set_text(s, 0, flags=get_hinting_flag())
#     195 font.draw_glyphs_to_bitmap(
#     196     antialiased=gc.get_antialiased())
#     197 d = font.get_descent() / 64.0
#
# KeyboardInterrupt:

# %%
# Out:
# [[0.6407926581549818]
#  [0.8874116120153563]
#  [--]
#  [0.48663060660552493]
#  [--]
#  [0.9161434353205622]
#  [0.5918955913518339]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [0.3921632303875383]
#  [--]
#  [0.696305015785703]
#  [0.8117762487632525]
#  [--]
#  [--]
#  [0.08668347884985661]
#  [0.01193579638983755]
#  [--]
#  [--]
#  [0.9658526875715345]
#  [--]
#  [0.27954724294124744]
#  [--]
#  [--]
#  [0.0746614801738189]
#  [0.7865644677368235]
#  [--]
#  [0.36678317422380025]
#  [--]
#  [0.6965072583993243]
#  [0.9889479456932216]
#  [0.4955708829726174]
#  [0.09155677426839226]
#  [--]
#  [0.0416299475162647]
#  [0.0957092115803656]
#  [0.31774385493268553]
#  [--]
#  [--]
#  [0.09808466549417638]
#  [--]
#  [--]
#  [--]
#  [0.3596589625012969]
#  [--]
#  [--]
#  [--]
#  [--]
#  [0.20785029194776772]
#  [0.5624549188217096]
#  [--]
#  [0.7304249127720488]
#  [--]
#  [0.31832124196425593]
#  [--]
#  [0.7897472710384268]
#  [--]
#  [0.6081360313028504]
#  [--]
#  [0.4092566162013558]
#  [--]
#  [--]
#  [0.16292722410070748]
#  [--]
#  [--]
#  [--]
#  [0.8370625994542165]
#  [--]
#  [--]
#  [--]
#  [--]
#  [0.3021539320172282]
#  [0.9109591764941979]
#  [--]
#  [--]
#  [--]
#  [0.18914457406845997]
#  [--]
#  [--]
#  [--]
#  [--]
#  [0.9355908321878194]
#  [0.7324068818258933]
#  [0.5720863681700539]
#  [0.4748170766832813]
#  [--]
#  [0.6043577388856184]
#  [0.5047790616528836]
#  [0.5138656187317052]
#  [0.34249573198955685]
#  [0.14685028031791247]
#  [0.6608923890331754]
#  [0.019629905831105132]
#  [--]
#  [0.41018145194498823]
#  [--]
#  [--]]

# %%
## change coordinates of plots to local coordinates:
#results.set_plot_localcoords(True)
## only plot a certain Area Of Interest of the complete grid
#results.set_aoi([20,445,20,220])

# example usage map plotting
# fig, ax = results.fig_cross_var('zs','[m]')
fig, ax = results.fig_profile_change(iy=0)

# #fig, ax = results.fig_map_diffvar('zb', '$\Delta z_b$ [m]')

# fig, ax = results.fig_cross_var('H', 2, iy=5, coord=None, plot_ref_bathy=True, zmin=-25)

# fig, ax = results.fig_profile_change(iy=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 8
#       1 ## change coordinates of plots to local coordinates:
#       2 #results.set_plot_localcoords(True)
#       3 ## only plot a certain Area Of Interest of the complete grid
#    (...)
#       6 # example usage map plotting
#       7 # fig, ax = results.fig_cross_var('zs','[m]')
# ----> 8 fig, ax = results.fig_profile_change(iy=0)
#      10 # #fig, ax = results.fig_map_diffvar('zb', '$\Delta z_b$ [m]')
#      11
#      12 # fig, ax = results.fig_cross_var('H', 2, iy=5, coord=None, plot_ref_bathy=True, zmin=-25)
#      13
#      14 # fig, ax = results.fig_profile_change(iy=5)
#
# NameError: name 'results' is not defined

# %%
import os
import xarray as xr
import numpy as np

# Define the ranges for each variable
Hm0_range = np.arange(1, 3, 0.5)
Tp_range = np.arange(5, 16, 5)
cf_values = [0.01, 0.1]
zs0_range = np.arange(0, 1.6, 0.2)

# Initialize an empty dictionary to store results
results_dict = {}

# Nested loop through each variable
for Hm0 in Hm0_range:
    for Tp in Tp_range:
        for cf in cf_values:
            for zs0 in zs0_range:
                
                # Initialize an empty list to store depths and corresponding x values
                bathy_list = []
                for i in range(4, 69,4):
                    sheet_name = f'PR_{i:02d}' 
                    # Generate folder name based on variable values
                    folder_name = f'{sheet_name}+Hs={Hm0:.3g}-Tp={Tp:.3g}-cf={cf:.3g}-zs0={zs0:.3g}'
                    ## load data
                    bathy_df = dfs[sheet_name]
                    # Extract depths from the DataFrame and convert to numpy array
                    bathy = bathy_df['merged_depth'].values
                    # Reverse the bathy values
                    bathy = np.flip(bathy)

                    ## set bathy grid
                    nx = len(bathy)
                    dx = 1

                    x = np.linspace(0, (nx-1)*dx, nx)
                    sim_path = os.path.join('/mnt/d/KLD/', folder_name)
                    print(sim_path)

                    try:
                        # Define the path for the runxb.bat file
                        bat_file_path = os.path.join(sim_path, 'runxb.bat')

                        destination_folder = os.path.dirname(sim_path)

                        params_file_path = os.path.join(sim_path, 'params.txt')
                        xboutput_file_path = os.path.join(sim_path, 'xboutput.nc')
                        data = xr.open_dataset(xboutput_file_path)
                        zb100 = data.zb.sel(globaltime=100)

                        if i == 56 or i== 47:  # Adjust for profile 56
                            flat_indices = np.where((zb100.values[0] >= -5.5) & (zb100.values[0] <= -3.5))
                        else:
                            flat_indices = np.where((zb100.values[0] >= -2) & (zb100.values[0]<= -0.4))  

                        output_point = flat_indices[0][-1]
                        flat_depth = np.mean(bathy[flat_indices])
                        flat_fit = np.poly1d(np.array([0, flat_depth]))     

                        model_time = data.globaltime.values
                        water_level = data.zs.isel(globalx=output_point)
                        water_level_init = data.zs.isel(globalx=1)
                        bed_level = data.zb.isel(globalx=output_point)
                        Hs = 4 * np.sqrt(np.var(water_level.values))
                        Setup = np.mean(water_level.values) - np.mean(water_level_init.values)
                        
                        # Store results in the dictionary with a tuple key
                        key = (sheet_name, Hm0, Tp, cf, zs0)
                        results_dict[key] = {'Setup': Setup, 'Hs': Hs}
                        print('works')

                    except FileNotFoundError:
                        print(f"Folder '{folder_name}' not found. Skipping...")
                        continue
# Out:
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=5-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_04+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_08+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_12+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_16+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_20+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_24+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_28+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_32+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_36+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_40+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_44+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_48+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_52+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_56+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_60+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_64+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_68+Hs=1-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# Folder 'PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=0.8' not found. Skipping...
# /mnt/d/KLD/PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# Folder 'PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=0.8' not found. Skipping...
# /mnt/d/KLD/PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# Folder 'PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=0.8' not found. Skipping...
# /mnt/d/KLD/PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# Folder 'PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=0.8' not found. Skipping...
# /mnt/d/KLD/PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# Folder 'PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=0.8' not found. Skipping...
# /mnt/d/KLD/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# Folder 'PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=0.8' not found. Skipping...
# /mnt/d/KLD/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# Folder 'PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=0.8' not found. Skipping...
# /mnt/d/KLD/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.8
# Folder 'PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=0.8' not found. Skipping...
# /mnt/d/KLD/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_64+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=1
# Folder 'PR_68+Hs=1.5-Tp=5-cf=0.01-zs0=1' not found. Skipping...
# /mnt/d/KLD/PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_04+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_08+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_12+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_16+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_20+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_24+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_28+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_32+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_36+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_40+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_44+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_48+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_52+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_56+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# /mnt/d/KLD/PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=1.2
# Folder 'PR_60+Hs=1.5-Tp=5-cf=0.01-zs0=1.2' not found. Skipping...
# ...
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=10-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=10-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=10-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.01-zs0=0
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.01-zs0=0.2
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.01-zs0=0.4
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.01-zs0=0.6
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.01-zs0=0.8
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.01-zs0=1
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.01-zs0=1.2
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.01-zs0=1.4
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.1-zs0=0
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.1-zs0=0.2
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.1-zs0=0.4
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.1-zs0=0.6
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.1-zs0=0.8
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.1-zs0=1
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.1-zs0=1.2
# works
# /mnt/d/KLD/PR_04+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_08+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_12+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_16+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_20+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_24+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_28+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_32+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_36+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_40+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_44+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_48+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_52+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_56+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_60+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_64+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works
# /mnt/d/KLD/PR_68+Hs=2.5-Tp=15-cf=0.1-zs0=1.4
# works

# %%
print(key)
# Out:
# ('PR_01', 2.5, 15, 0.1, 1.4000000000000001)

# %%
results_dict['PR_08', 2.5, 10, 0.1, 1.4000000000000001]
# Out:
# {'Setup': 0.09697242573684073, 'Hs': 0.7072992820191952}
